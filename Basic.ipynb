# %%
x = 7
y = 5
print(not(x > 10))
print((1 + 2j) + (3 + 4j))
# Out:
# True
# (4+6j)

# %%
print(5 / 2)
print(5 // 2)
# Out:
# 2.5
# 2

# %%
print(5 % 2 )
print(-5 % 2)
# Out:
# 1
# 1

# %%
print(2 ** 3)
print(2 ** 3 ** 2) # (2 ** (3 ** 2))
print(3 ** 2)
print(2 ** 9)
# Out:
# 8
# 512
# 9
# 512

# %%
a = "jfbhbeb"
b = "jrfgergn"
#print(a - b) #unsupported operand type(s) for -: 'str' and 'str'

# %%
print(True and False)
print(False or True)
print(not False)
# Out:
# False
# True
# True

# %%
def func():print("Evaluated");
print(False and func())
print(True or func())
#Non-boolean operands
print(0 and "Hello")
print(1 or "Hello")
# Out:
# False
# True
# 0
# 1

# %%
x = 10 
x += 5
print(x)
x *= 2 
print(x)
# Out:
# 15
# 30

# %%
a = 10 
b = 5
print(a & b)
print(a | b)
bin(a | b)
print(a^b)
print(a << 1)
print(a >> 1)
# Out:
# 0
# 15
# 15
# 20
# 5

# %%
a = 256 
b = 256
print(a is b)
a = 257
b = 257
print(a is b)

#mutable
list1 = []
list2 = []
print(list1 is list2)
# Out:
# True
# False
# False

# %%
# Membership Operator
print(2 in [1,2,3])
print("a" not in "bc")
# Dict(keys)
print("key" in {"key":"Vishal"}) # case sensitive

#Edge case: Custom object
class C:
    def __contains__(self, item):return True
print(1 in C())
# Out:
# True
# True
# True
# True

# %%
num = int(input("Enter number for even and odd"))
for n in range(1, num +1):
    if n % 2 == 0:
        print(n," is even number")
    elif n % 2 != 0:
        print(n,"is an odd number")
# Out:
# Enter number for even and odd 10
# 1 is an odd number
# 2  is even number
# 3 is an odd number
# 4  is even number
# 5 is an odd number
# 6  is even number
# 7 is an odd number
# 8  is even number
# 9 is an odd number
# 10  is even number

# %%
# Ternary Operator 
print("Even" if 4 % 2 == 0 else"Odd")
# Out:
# Even

# %%
#Operator OverLoading
import operator
print(operator.add(5,3))

class Vector:
    def __init__(self, x): self.x = x
    def __add__(self, other):return Vector(self.x + other.x)
# Out:
# 8

# %%
tuple1 = (1,2,3,54,32,23,4,4)
tuple2 = (21,2,3,4,3,4,5,6)
commonElement0 = set()
commonElement1 = []
for item in tuple1:
    if item in tuple2:
        commonElement0.add(item)
        commonElement1.append(item)
        
        
print(commonElement0)
print(commonElement1)
# Out:
# {2, 3, 4}
# [2, 3, 4, 4]

# %%
print(not 0)
# Out:
# True

# %%
age = 17.5
if age > 18:
    print("hello")
if age > 17 and age < 18:
    print("hello world")
else:
    print("Hello Sir")
# Out:
# hello world
