# %%
#
class Treenode:
    def __init__(self,value):
        self.right = None
        self.left = None
        self.value = value
        
    def insert(self , value):
        if value < self.value:
            if self.left is None:
                self.left = Treenode(value)
            else:
                self.left.insert(value)
        else:
            if self.right is None:
                self.right = Treenode(value)
            else:
                self.right.insert(value)
                
    def inorder_traversal(self):   # works on binary search trees only cuz prinnting in ascending order
        if self.left:
            self.left.inorder_traversal()
        print(self.value)
        if self.right:
            self.right.inorder_traversal()   
            
    def preorder_traversal(self):
        print(self.value)   #print every value first and the move to the next node to print (print from top to bottom)
        if self.left:
            self.left.preorder_traversal()
        if self.right:
            self.right.preorder_traversal()   
            
    def postorder_traversal(self):   #print when one path has been explored completely till the end and then print the value at the end (print from bottom to up)
        if self.left:
            self.left.postorder_traversal()
        if self.right:
            self.right.postorder_traversal()
        print(self.value)
        
    def find(self , value):
        if self.value < value:
            if self.right is None:
                return False
            else:
                return self.right.find(value)
        elif self.value > value:
            if self.left is None:
                return False
            else:
                return self.left.find(value)
        else:
            return True  , value , 'found'

# %%
# 94. Binary Tree Inorder Traversal
# Definition for a binary tree node.
class TreeNode:
     def __init__(self, val=0, left=None, right=None):
         self.val = val
         self.left = left
         self.right = right
class Solution:
    ans = []
    def __init__(self):
        self.ans = []
    def inorder(self, node):
        if node is None:
            return
        self.inorder(node.left)
        self.ans.append(node.val)
        self.inorder(node.right)

    def inorderTraversal(self, root: Optional[TreeNode]) -> List[int]:
        self.ans = []
        self.inorder(root)
        return self.ans

# %%
#110

# %%
#98
