# %%
stack = []

def push(num:int):
    stack.append(num)
    
def pop():
    if not stack:
        print("stack is empty")
    return stack.pop()
def top():
    if not stack:
        print("stack is empty")
    return stack[-1]

def size():
    return len(stack)

# %%
#push(5)
print(size())
# Out:
# 3
