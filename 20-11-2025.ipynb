# %%
# 1. Number Classification
#Write a program that asks the user for a number and:
num = int(input("Enter the number:"))
if num > 0:
    print("Positive")
elif num < 0:
    print("negative")
else:
    print("Zero")
# Out:
# Enter the number: -1
# negative

# %%
# 2. Simple Grading System

# Ask the user for their score (0–100).
# Using if/elif/else:
grad = int(input("Enter the grade"))

if grad >= 90 :
    print("Grade A")
elif grad >= 75 and grad <= 80:
    print("Grade B")
elif grad >= 50 and grad <= 74:
    print("Grade C")
else:
    print("fail")
# Out:
# Enter the grade 90
# Grade A

# %%
#3. Even, Odd, or Not an Integer
num = input("Enter the number:-")
try:
    num = int(num)
    if num % 2 == 0:
        print("Number is even:")
    else:
        print("Number is odd")
except ValueError:
    print("Invalid number")
if type(num) == str:
    print("asdhjbjshfdb")
# Out:
# Enter the number:- 123
# Number is odd

# %%
#4. Age Group Categorizer
age = input("Enetr your age:")
try:
    age = int(age)
    if age <= 13:
        print("Child")
    elif age >= 13 and age <= 19:
        print("Teenager")
    elif age  >= 20 and age <= 59:
        print("Adult")
    elif age >= 60 and age <= 120:
        print("Senior")
    else:
        print("The End")
        
except ValueError:
    print("Invalid Number")
# Out:
# Enetr your age: 13
# Child

# %%
# 5. Login Password Checker
password = input("Enetr the password:")

if password == "python123":
    print("Login Successful")
else:
    print("Incorrect Password")
# Out:
# Enetr the password: python123
# Login Successful
