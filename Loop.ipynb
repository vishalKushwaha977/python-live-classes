# %%
num = 500
for n in range(1 ,num + 1):
    if not n % 5 and not n % 3:
        print(n ," foobar")
    elif not n % 3:
        print(n,"foo")
    elif not n % 5:
        print(n,"bar")
    else:
        print(n)
# Out:
# 1
# 2
# 3 foo
# 4
# 5 bar
# 6 foo
# 7
# 8
# 9 foo
# 10 bar
# 11
# 12 foo
# 13
# 14
# 15  foobar
# 16
# 17
# 18 foo
# 19
# 20 bar
# 21 foo
# 22
# 23
# 24 foo
# 25 bar
# 26
# 27 foo
# 28
# 29
# 30  foobar
# 31
# 32
# 33 foo
# 34
# 35 bar
# 36 foo
# 37
# 38
# 39 foo
# 40 bar
# 41
# 42 foo
# 43
# 44
# 45  foobar
# 46
# 47
# 48 foo
# 49
# 50 bar
# 51 foo
# 52
# 53
# 54 foo
# 55 bar
# 56
# 57 foo
# 58
# 59
# 60  foobar
# 61
# 62
# 63 foo
# 64
# 65 bar
# 66 foo
# 67
# 68
# 69 foo
# 70 bar
# 71
# 72 foo
# 73
# 74
# 75  foobar
# 76
# 77
# 78 foo
# 79
# 80 bar
# 81 foo
# 82
# 83
# 84 foo
# 85 bar
# 86
# 87 foo
# 88
# 89
# 90  foobar
# 91
# 92
# 93 foo
# 94
# 95 bar
# 96 foo
# 97
# 98
# 99 foo
# 100 bar
# 101
# 102 foo
# 103
# 104
# 105  foobar
# 106
# 107
# 108 foo
# 109
# 110 bar
# 111 foo
# 112
# 113
# 114 foo
# 115 bar
# 116
# 117 foo
# 118
# 119
# 120  foobar
# 121
# 122
# 123 foo
# 124
# 125 bar
# 126 foo
# 127
# 128
# 129 foo
# 130 bar
# 131
# 132 foo
# 133
# 134
# 135  foobar
# 136
# ...
