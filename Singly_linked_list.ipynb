# %%
class Node:
    def __init__(self, val):
        self.val = val
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        
    def insertAtEnd(self, val):
        new_node = Node(val)
        if not self.head:
            self.head = new_node
            return
            
        current_node = self.head
        while current_node.next:
            current_node = current_node.next
            print(current_node)
        current_node.next = new_node
l1 = LinkedList()

# %%
l1.insertAtEnd(7)

# %%
l1.head.val
# Out:
# 7

# %%
#206. Reverse Linked List
class ListNode:
    def __init__(self,val =0 ,next = None):
        self.val = val
        self.next = next
class Solution:
    
    def print_List(self,head):
        curr = head
        while curr:
            print(curr.val,end="-->")
            curr = curr.next
        print("None")
       
    def reverseList(self,head):
        prev = None
        curr = head
        self.print_List(head)
        while curr:
            nxt = curr.next
            curr.next = prev
            prev = curr
            curr = nxt
        self.print_List(prev)
        
        return prev

# %%
head = ListNode(1, ListNode(2, ListNode(3)))
sol = Solution()
sol.reverseList(head)
# Out:
# 1-->2-->3-->None
# 3-->2-->1-->None

# %%
#141
class Node:
    def __init__(self,val =0,next = None):
        self.val = val
        self.next = None

def create_linked_list(values, pos):
    head = Node(values[0])
    current = head
    cycle_node = None

    for i in range(1, len(values)):
        current.next = Node(values[i])
        current = current.next
        if i == pos:
            cycle_node = current
    if pos == 0:
        cycle_node = head

    if pos != -1:
        current.next = cycle_node 
    return head
    
class CycleLinkedList: # this is the main logic here 
    
    def hasCycle(self,head):
        slow = head
        fast = head
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
            if slow == fast:
                return True
        return False    

values = [3, 2, 0, -4]
pos = 1
head = create_linked_list(values, pos) # call this method to make cycle node 

obj = CycleLinkedList()
print(obj.hasCycle(head))
# Out:
# True

# %%
#234.Palindrome Linked List
from typing import Optional
class Node:
    def __init__(self, value = 0,next = None):
        self.value = value
        self.next = None
        
class LinkedList:
    def isPalindrome(self,head:Optional[Node]):
        slow = head
        fast = head
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
            
        prev = None
        while slow:
            nxt = slow.next
            slow.next = prev
            prev = slow
            slow = nxt

        left = head 
        right = prev
        
        while right:
            if left.value != right.value:
                return False
            left = left.next
            right = right.next
            
        return True        
# Create nodes manually
n1 = Node(1)
n2 = Node(2)
n3 = Node(2)
n4 = Node(1)

# Connect nodes
n1.next = n2
n2.next = n3
n3.next = n4

head = n1

# Test
ll = LinkedList()
print(ll.isPalindrome(head)) 

# True
# Out:
# True

# %%
#19  Remove Nth Node From End of List
from typing import Optional
class Node:
    def __init__(self, val = 0,next = None):
        self.val = val
        self.next = None
        
class Solution:
    def removeNthFromEnd(self, head: Optional[Node], n: int) -> Optional[Node]:
        dummy = Node(0)
        dummy.next = head

        fast = dummy
        slow = dummy
        for _ in range(n + 1):
            fast = fast.next
            
        while fast:
            fast = fast.next
            slow = slow.next
        slow.next = slow.next.next # this is for remove node

        return dummy.next
n1 = Node(1)
n2 = Node(2)
n3 = Node(3)
n4 = Node(4)
n5 = Node(5)
n1.next = n2
n2.next = n3
n3.next = n4
n4.next = n5
head = n1
ll = Solution()
new_head = ll.removeNthFromEnd(head, 2)

# ---- Print Linked List ----
current = new_head
while current:
    print(current.val, end=" -> ")
    current = current.next
print("None")
# Out:
# 1 -> 2 -> 3 -> 5 -> None

# %%
#24
from typing import Optional
class Node:
    def __init__(self, val = 0, next = None):
        self.val = val
        self.next = None
class linkedList:
    def SwapNode(self, head: Optional[Node]):
        dummy = Node(0)
        dummy.next = head
        
        prev = dummy
        
        while prev.next and prev.next.next:
            first = prev.next
            sec = first.next

            prev.next = sec
            first.next = sec.next
            sec.next = first

            prev = first

        return dummy.next

# %%
# 61. Rotate List

# %%
# 82. Remove Duplicates from Sorted List II
